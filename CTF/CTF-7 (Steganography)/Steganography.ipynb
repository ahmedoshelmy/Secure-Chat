# %%
from PIL import Image
import matplotlib.pyplot as plt

# Read the image
img = Image.open("pepo_evil.jpg")
width, height = img.size
msg = ''
for x in range(height):
    for y in range(width):
        r, g, b = img.getpixel((x, y))
        if r % 2 == 1:
            msg += '1'
        else:
            msg += '0'

        if g % 2 == 1:
            msg += '1'
        else:
            msg += '0'

        if b % 2 == 1:
            msg += '1'
        else:
            msg += '0'


# Convert the message to a string
msg = ''.join([chr(int(msg[i:i+8], 2)) for i in range(0, len(msg), 8)])
print(msg)
# Out:
# ÿÿÿÿÿÿãCUÙ´ê¨Ë"6I)[K%
# $I$II$(àãÿÿÿÿÿÿÿüÀÙö[ït	)ôÝßÛ·öíµ¥6*ñ[m¶$I¶Ûm8¨ÿÿÿÿÿÿÿ7øÌ5(asþÖ1II$ÿòRI$8jô­Ûm¶$I¶ÛmÄäDÿÿÿÿÿÿ¯4ÍËnRÂÑöI)$ÿòR$¤Q¥Î$IÛm¶I$9ÿÿÿÿÿÿe sT¬ïY9P> $À¢$¤Ip´Ûm¶Ûm¶Ûm¶8âVÿÿÿÿÿÿjp::keg?q5AÿßÛmÛ]nÛo®]$I$I$IÈÿÿÿÿÿÿ+{÷n¾÷_²5|ü$	f°#Ûm¶Ûm¶Ûm¶Û¶ÿÿÿÿÿÿpj»ñýpzødK$pbÛm¶$IÛm¶;vÿÿÿÿÇk¨ÿDs÷b¨ÊJÛÿõUmH`)$I$I$I$ÿÿÿÿþ9DØ+
# °ª¤d*Jì«$I$I$I$ÿÿÿÿÿù¡S Ûî£
# îD®Ùw©¼(2ÑÞ32J$I$IÿöÛëöËDN@ièðM$ÂÖæÇ17jIm$I$IÿöÛþwÐ%x¬®;:JØì6R½I6ÊII$IÿöÛ_ð+5mH\ÆÞÊ§PvL=ÓH¡½A6Ê$I$IÿöÛþwòKðK¿|xÝ7o@øØºÏÚ32J$I$IÿöÛêyõBe>Ê'
# ...

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Read the image
img = Image.open("pepo_evil.jpg")

img = img.convert('L')

width, height = img.size

msg = ''

for x in range(width):
    for y in range(height):
        val = img.getpixel((x, y))
        if val % 2 == 1:
            msg += '1'
        else:
            msg += '0'

msg = [msg[i:i+8] for i in range(0, len(msg), 8)]
msg = ''.join([chr(int(c, 2)) for c in msg])

clean_msg = ''

for c in msg:
    if c < 'z' and c > 'A':
        clean_msg += c

print(clean_msg)

plt.imshow(img, cmap='gray')
plt.show()
# Out:
# vlpnHHvl[sZdWNgSghaNXyVKgxIZj_w^yeqHt[bHTNWuITMcnLreuhpbXsLvoVmfOQSSeho^evgfTqbBonE^sWGpBx]GWf_JxkuxmRjl^lR^gDkLlrpCeykSkoiW[TKOYvH`kFi_OqsvTqGQXVC`kiXaDpnh]JLPhTEQxr[WXiplN]BmtCOwZZCLNfFKv\WvVNZdMkPHx[OrKQyELXODHPpfSWTVuhGp^wBknFGd

# %%
from PIL import Image
import matplotlib.pyplot as plt

# Read the image
img = Image.open("pepo_evil.jpg")

width, height = img.size

msg = ''

# r_msg = ''
# g_msg = ''
# b_msg = ''

for x in range(height):
    for y in range(width):
        r, g, b = img.getpixel((x, y))
        if r % 2 == 1:
            msg += '1'
            r_msg += '1'
        else:
            msg += '0'
            r_msg += '0'

        if g % 2 == 1:
            msg += '1'
            g_msg += '1'
        else:
            msg += '0'
            g_msg += '0'

        if b % 2 == 1:
            msg += '1'
            b_msg += '1'
        else:
            msg += '0'
            b_msg += '0'


# Convert the message to a string
msg = ''.join([chr(int(msg[i:i+8], 2)) for i in range(0, len(msg), 8)])
# r_msg = ''.join([chr(int(r_msg[i:i+8], 2)) for i in range(0, len(r_msg), 8)])
# g_msg = ''.join([chr(int(g_msg[i:i+8], 2)) for i in range(0, len(g_msg), 8)])
# b_msg = ''.join([chr(int(b_msg[i:i+8], 2)) for i in range(0, len(b_msg), 8)])

# clean_msg = ''
# clean_r_msg = ''
# clean_g_msg = ''
# clean_b_msg = ''

# for i in range(len(msg)):
#     if (ord(msg[i]) <= 90 and ord(msg[i]) >= 65) or (ord(msg[i]) <= 122 and ord(msg[i]) >= 97) or ord(msg[i]) == 32:
#         clean_msg += msg[i]

# for i in range(len(r_msg)):
#     if (ord(r_msg[i]) <= 90 and ord(r_msg[i]) >= 65) or (ord(r_msg[i]) <= 122 and ord(r_msg[i]) >= 97) or ord(r_msg[i]) == 32:
#         clean_r_msg += r_msg[i]

# for i in range(len(g_msg)):
#     if (ord(g_msg[i]) <= 90 and ord(g_msg[i]) >= 65) or (ord(g_msg[i]) <= 122 and ord(g_msg[i]) >= 97) or ord(g_msg[i]) == 32:
#         clean_g_msg += g_msg[i]

# for i in range(len(b_msg)):
#     if (ord(b_msg[i]) <= 90 and ord(b_msg[i]) >= 65) or (ord(b_msg[i]) <= 122 and ord(b_msg[i]) >= 97) or ord(b_msg[i]) == 32:
#         clean_b_msg += b_msg[i]

    
# print(g_msg)
